# %%
#REDACTION PROTOCOL
ENGINEER = "SINUES"
byte_val = 83
loops = 11
seed = 8 
redacted_output = ""

for char in ENGINEER.upper():
    if char in "AEIOU":
        redacted_output += str(seed)
    else:
        redacted_output += char

print(f"Original Surname: {ENGINEER}")
print(f"SEED_NUM (B): {seed}")
print(f"Redacted Output: {redacted_output}")
# Out:
# Original Surname: SINUES
# SEED_NUM (B): 8
# Redacted Output: S8N88S

# %%
A = byte_val 
B = seed 
C = loops    

verification_hash = (A * B) - C
print(f"First Letter ASCII (A): {A}")
print(f"SEED_NUM (B): {B}")
print(f"Total Loops (C): {C}")
print(f"Forensic Signature: {verification_hash}")
# Out:
# First Letter ASCII (A): 83
# SEED_NUM (B): 8
# Total Loops (C): 11
# Forensic Signature: 653

# %%
correct_password = "TOXIC"
attempts = 0

while True:
    user_input = input("Enter Password: ")
    attempts = 3
    if user_input == correct_password:
        print("Unlocked.")
        break # This breaks the infinite loop
    else:
        print("Access Denied.")
# Out:
# Unlocked.
